# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
import seaborn as sn
from matplotlib.pyplot import figure
import seaborn as sns
sns.set_style('darkgrid')
plt.figure(figsize=(10,3),dpi=200)
import pandas as pd
df=pd.read_excel('D:\Research_work\COVID_paper\My_covid_research2/validation/forecasting\covid_534days.xlsx')


dater=np.genfromtxt('optimal_state_trajecotry.csv',delimiter=',')

r_dater=np.genfromtxt('D:\Research_work\COVID_paper\My_covid_research/approximation_model/future_data_ref.csv',delimiter=',')

dates=df['DATE'].tolist()
# dates=dates.reverse()

dates=dates[-16:-1]
# reverse list
dates=dates[::-1]



plt.plot(dates, np.flip(dater[:,1]), color='red', label='I(optimal)')
plt.plot(dates, np.flip(r_dater[:,1]), color='blue', label='I(original)')
plt.legend(loc='lower left')

# %%
plt.figure(figsize=(10,3),dpi=200)
plt.plot(dates, np.flip(dater[:,4]), color='red', label='D(optimal)')
plt.plot(dates, np.flip(r_dater[:,4]), color='blue', label='D(original)')
plt.legend(loc='lower left')
